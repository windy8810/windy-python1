# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel("123.xlsx.xlsx",header=2)
df.columns
df2=df[['1年以上債務未償餘額', '短期債務未償餘額', '平均每人負擔債務']]

# %%
df.head()
# Out:
#            項目    1年以上債務未償餘額      短期債務未償餘額  平均每人負擔債務  自償性債務未償餘額\n（含非營業特種基金）
# 0  截至106年1月底止  6.150000e+10  3.296885e+10   34138.0           3.266973e+10
# 1  截至106年2月底止  6.150000e+10  3.200000e+10   33767.0           3.266973e+10
# 2  截至106年3月底止  6.650000e+10  3.037811e+10   34970.0           3.515672e+10
# 3  截至106年4月底止  6.650000e+10  2.904961e+10   34468.0           3.559005e+10
# 4  截至106年5月底止  6.650000e+10  2.500000e+10   32990.0           3.589005e+10

# %%
fig, ax = plt.subplots(figsize=(20, 10))
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']
plt.title("台中債務訊息",size=36)
plt.ylabel('新台幣',size=20)
sns.lineplot(data=df2)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-79c83efb9910> in <module>
# ----> 1 df.index()
#
# TypeError: 'Index' object is not callable
