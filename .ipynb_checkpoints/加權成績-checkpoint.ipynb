# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[86.5,79.4,88.2,96.5,86.3,76,8,96.1,78.5,82.4,88.6]
y=["國文","英文","數甲","數乙","物理","化學","生物","歷史","地理","公民"]
z=["土語","財政","金融","國貿","會計","法律","公行","應數","教育"]
s=[[2, 2, 0, 1, 0, 0, 0, 1, 1, 0],[1, 1.5, 0, 1.5, 0, 0, 0, 0, 0, 0],[1, 1.5, 0, 2, 0, 0, 0, 0, 0, 0],
[1.5, 2, 0, 2, 0, 0, 0, 0, 0, 0],[1.5, 2, 0, 2, 0, 0, 0, 1, 1, 0],
[1, 2, 0, 1, 0, 0, 0, 1, 0, 1],
[1, 1.5, 0, 1.25, 0, 0, 0, 0, 0, 1.25],
[1, 1, 1.5, 0, 1, 1, 0, 0, 0, 0],
[1.5, 2, 0, 1.25, 0, 0, 0, 1, 1, 0]]
df=pd.DataFrame(s,index=z,columns=y)
df
# Out:
#      國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民
# 土語  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00
# 財政  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00
# 金融  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00
# 國貿  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00
# 會計  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00
# 法律  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00
# 公行  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25
# 應數  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00
# 教育  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00

# %%
sum=0
score=[]
for i in range(len(z)):
    score.append(round(sum,3))
    sum=0
    for j in range(len(y)):
        a=x[j]*s[i][j]
        sum+=a
score.append(sum)
score.remove(score[0])
df["加權分數"]=score
df
# Out:
#      國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民     加權分數
# 土語  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00  602.900
# 財政  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00  350.350
# 金融  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00  398.600
# 國貿  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00  481.550
# 會計  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00  656.150
# 法律  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00  520.300
# 公行  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25  429.225
# 應數  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00  460.500
# 教育  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00  583.775
